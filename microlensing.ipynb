# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv("microlensing.csv")

# %%
df.head(15)
# Out:
#                   pl_name         rastr          ra         decstr        dec  \
# 0    KMT-2019-BLG-1953L b  17h56m27.90s  269.116250  -28d12m04.00s -28.201111
# 1     MOA-2013-BLG-605L b  17h58m42.85s  272.019257  -29d23m53.66s -29.731583
# 2    KMT-2019-BLG-1953L b  17h56m27.90s  269.116250  -28d12m04.00s -28.201111
# 3    OGLE-2005-BLG-390L b   17h54m19.2s  268.579958     -30d22m38s -30.377306
# 4   OGLE-2012-BLG-0950L b  18h08m04.62s  272.019257   -29d43m53.7s -29.731583
# 5   OGLE-2016-BLG-1067L b  18h12m49.08s  273.204500   -27d00m45.5s -27.012639
# 6    OGLE-2005-BLG-071L b  17h50m09.77s  267.540708   -34d40m23.5s -34.673194
# 7   OGLE-2018-BLG-0740L b  18h08m42.47s  272.176958   -29d50m08.9s -29.835806
# 8   OGLE-2016-BLG-1190L b  17h58m52.30s  269.717926   -27d36m48.8s -27.613556
# 9   OGLE-2017-BLG-0373L b  17h57m19.06s  269.329407   -31d57m06.2s -31.951723
# 10   OGLE-2007-BLG-368L b  17h56m25.96s  269.108167   -32d14m14.7s -32.237417
# 11  OGLE-2018-BLG-0596L b  17h56m13.33s  269.055542   -29d11m56.7s -29.199083
# 12  OGLE-2013-BLG-0911L b  17h55m31.98s  268.883250   -29d15m13.8s -29.253833
# 13    MOA-2010-BLG-353L b  18h05m12.94s  271.303917  -27d17m35.64s -27.293233
# 14   KMT-2016-BLG-2142L b  17h52m26.88s  268.112000  -29d23m04.42s -29.384562
#
#     pl_massj  pl_masse  pl_orbsmax  st_mass  sy_dist  ...  sy_vmag  sy_icmag  \
# 0        NaN       NaN         NaN      NaN      NaN  ...      NaN       NaN
# 1    0.06475     20.58       4.180    0.198   3550.0  ...      NaN       NaN
# 2        NaN       NaN         NaN      NaN      NaN  ...      NaN       NaN
# 3    0.01700      5.50       2.600    0.220   6600.0  ...      NaN       NaN
# 4    0.11000     36.00       2.700    0.550   3400.0  ...      NaN       NaN
# 5    0.43000    140.00       1.710    0.310   3780.0  ...      NaN       NaN
# 6    3.80000   1200.00       3.600    0.460   3200.0  ...      NaN       NaN
# 7    1.10000    350.00       1.500    0.470   7200.0  ...    18.21     17.13
# 8   13.38000   4253.00       2.170    0.880   6770.0  ...      NaN       NaN
# 9    0.18900     60.10       2.575    0.276   5810.0  ...      NaN       NaN
# 10   0.06000     20.00       2.800    0.640   5900.0  ...    17.71       NaN
# 11   0.04383     13.93       0.970    0.231   5650.0  ...      NaN       NaN
# 12       NaN       NaN         NaN      NaN      NaN  ...    26.42     22.80
# 13   0.27000     86.00       1.720    0.180   6430.0  ...      NaN       NaN
# 14       NaN       NaN         NaN      NaN      NaN  ...      NaN       NaN
#
#     sy_jmag  sy_hmag  sy_kmag  ml_extvfld  ml_extifld  ml_extjfld  ml_exthfld  \
# 0       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 1       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 2       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 3       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 4       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 5       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 6       NaN      NaN      NaN         NaN       1.200         NaN         NaN
# 7       NaN      NaN      NaN         NaN       0.500         NaN         NaN
# 8       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 9       NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 10      NaN      NaN      NaN         NaN       1.430         NaN         NaN
# 11      NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 12      NaN    19.99    19.64         NaN       1.514         NaN         NaN
# 13      NaN      NaN      NaN         NaN       1.180         NaN         NaN
# 14      NaN      NaN      NaN         NaN         NaN         NaN         NaN
#
#     ml_extkfld
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
#
# [15 rows x 55 columns]

# %%
print(df.size)
df.shape
# Out:
# 36905
# (671, 55)

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 55 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pl_name        0 non-null      object
#  1   rastr          0 non-null      object
#  2   ra             0 non-null      float64
#  3   decstr         0 non-null      object
#  4   dec            0 non-null      float64
#  5   pl_massj       0 non-null      float64
#  6   pl_masse       0 non-null      float64
#  7   pl_orbsmax     0 non-null      float64
#  8   st_mass        0 non-null      float64
#  9   sy_dist        0 non-null      float64
#  10  ml_dists       0 non-null      float64
#  11  ml_tsepmin     0 non-null      float64
#  12  ml_sepminnorm  0 non-null      float64
#  13  ml_xtimeein    0 non-null      float64
#  14  ml_radsnorm    0 non-null      float64
#  15  ml_sepinsnorp  0 non-null      float64
#  16  ml_massratio   0 non-null      float64
#  17  ml_angstlax    0 non-null      float64
#  18  ml_magis       0 non-null      float64
#  19  ml_magibl      0 non-null      float64
#  20  ml_radeinang   0 non-null      float64
#  21  ml_pmrells     0 non-null      float64
#  22  glon           0 non-null      float64
#  23  glat           0 non-null      float64
#  24  ml_plxrel      0 non-null      float64
#  25  ml_plxmicro    0 non-null      float64
#  26  ml_plxmicron   0 non-null      float64
#  27  ml_plxmicroe   0 non-null      float64
#  28  ml_dsdt        0 non-null      float64
#  29  ml_dalphadt    0 non-null      float64
#  30  ml_radsang     0 non-null      float64
#  31  ml_radsphy     0 non-null      float64
#  32  ml_xtimesrc    0 non-null      float64
#  33  ml_efftime     0 non-null      float64
#  34  ml_pms         0 non-null      float64
#  35  ml_magvs       0 non-null      float64
#  36  ml_magvso      0 non-null      float64
#  37  ml_magiso      0 non-null      float64
#  38  ml_magjs       0 non-null      float64
#  39  ml_magjso      0 non-null      float64
#  40  ml_maghs       0 non-null      float64
#  41  ml_maghso      0 non-null      float64
#  42  ml_magks       0 non-null      float64
#  43  ml_magkso      0 non-null      float64
#  44  ml_magibase    0 non-null      float64
#  45  sy_vmag        0 non-null      float64
#  46  sy_icmag       0 non-null      float64
#  47  sy_jmag        0 non-null      float64
#  48  sy_hmag        0 non-null      float64
#  49  sy_kmag        0 non-null      float64
#  50  ml_extvfld     0 non-null      float64
#  51  ml_extifld     0 non-null      float64
#  52  ml_extjfld     0 non-null      float64
#  53  ml_exthfld     0 non-null      float64
#  54  ml_extkfld     0 non-null      float64
# dtypes: float64(52), object(3)
# memory usage: 0.0+ bytes

# %%
column_names = df1.columns
print(column_names)
# Out:
# Index(['pl_name', 'rastr', 'ra', 'decstr', 'dec', 'pl_massj', 'pl_masse',
#        'pl_orbsmax', 'st_mass', 'sy_dist', 'ml_dists', 'ml_tsepmin',
#        'ml_sepminnorm', 'ml_xtimeein', 'ml_radsnorm', 'ml_sepinsnorp',
#        'ml_massratio', 'ml_angstlax', 'ml_magis', 'ml_magibl', 'ml_radeinang',
#        'ml_pmrells', 'glon', 'glat', 'ml_plxrel', 'ml_plxmicro',
#        'ml_plxmicron', 'ml_plxmicroe', 'ml_dsdt', 'ml_dalphadt', 'ml_radsang',
#        'ml_radsphy', 'ml_xtimesrc', 'ml_efftime', 'ml_pms', 'ml_magvs',
#        'ml_magvso', 'ml_magiso', 'ml_magjs', 'ml_magjso', 'ml_maghs',
#        'ml_maghso', 'ml_magks', 'ml_magkso', 'ml_magibase', 'sy_vmag',
#        'sy_icmag', 'sy_jmag', 'sy_hmag', 'sy_kmag', 'ml_extvfld', 'ml_extifld',
#        'ml_extjfld', 'ml_exthfld', 'ml_extkfld'],
#       dtype='object')

# %%
df1.head(15)
# Out:
# Empty DataFrame
# Columns: [pl_name, rastr, ra, decstr, dec, pl_massj, pl_masse, pl_orbsmax, st_mass, sy_dist, ml_dists, ml_tsepmin, ml_sepminnorm, ml_xtimeein, ml_radsnorm, ml_sepinsnorp, ml_massratio, ml_angstlax, ml_magis, ml_magibl, ml_radeinang, ml_pmrells, glon, glat, ml_plxrel, ml_plxmicro, ml_plxmicron, ml_plxmicroe, ml_dsdt, ml_dalphadt, ml_radsang, ml_radsphy, ml_xtimesrc, ml_efftime, ml_pms, ml_magvs, ml_magvso, ml_magiso, ml_magjs, ml_magjso, ml_maghs, ml_maghso, ml_magks, ml_magkso, ml_magibase, sy_vmag, sy_icmag, sy_jmag, sy_hmag, sy_kmag, ml_extvfld, ml_extifld, ml_extjfld, ml_exthfld, ml_extkfld]
# Index: []
#
# [0 rows x 55 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Select relevant features and target variable
features = df1[['pl_orbper', 'pl_rade', 'pl_orbeccen', 'pl_orbincl', 'pl_tranmid', 'pl_imppar', 'pl_trandep', 'pl_trandur', 'pl_ratdor', 'pl_ratror', 'sy_vmag', 'sy_kmag']]
target = df1['ttv_flag']

# %%
features.columns
# Out:
# Index(['pl_orbper', 'pl_rade', 'pl_orbeccen', 'pl_orbincl', 'pl_tranmid',
#        'pl_imppar', 'pl_trandep', 'pl_trandur', 'pl_ratdor', 'pl_ratror',
#        'sy_vmag', 'sy_kmag'],
#       dtype='object')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train a RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1757: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))

# %%
# Sample input data
sample_input = pd.DataFrame({
    'pl_orbper': [10.0],
    'pl_rade': [1.5],
    'pl_orbeccen': [0.1],
    'pl_orbincl': [89.0],
    'pl_tranmid': [2459000.0],
    'pl_imppar': [0.02],
    'pl_trandep': [0.01],
    'pl_trandur': [2.0],
    'pl_ratdor': [0.01],
    'pl_ratror': [0.1],
    'sy_vmag': [10.0],
    'sy_kmag': [8.0]
})

# Standardize the sample input
sample_input_scaled = scaler.transform(sample_input)

# Make predictions using the trained model
sample_output = model.predict(sample_input_scaled)

print("Sample Input:")
print(sample_input)
print("\nPredicted Output:")
print(sample_output)
# Out:
# Sample Input:
#    pl_orbper  pl_rade  pl_orbeccen  pl_orbincl  pl_tranmid  pl_imppar  \
# 0       10.0      1.5          0.1        89.0   2459000.0       0.02
#
#    pl_trandep  pl_trandur  pl_ratdor  pl_ratror  sy_vmag  sy_kmag
# 0        0.01         2.0       0.01        0.1     10.0      8.0
#
# Predicted Output:
# [0]

# %%
y_train.nunique()
# Out:
# 2
